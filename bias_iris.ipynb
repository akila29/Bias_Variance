# %%
from mlxtend.evaluate import bias_variance_decomp
import pandas as pd
from sklearn.metrics import mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %%
# We will be using the iris dataset from the scikit-learn toy Datasets 

from sklearn.datasets import load_iris

loaded_data = load_iris(as_frame=True)
data = loaded_data['data']
target = loaded_data['target']
data.head(), target.head()
# Out:
# (   sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
#  0                5.1               3.5                1.4               0.2
#  1                4.9               3.0                1.4               0.2
#  2                4.7               3.2                1.3               0.2
#  3                4.6               3.1                1.5               0.2
#  4                5.0               3.6                1.4               0.2,
#  0    0
#  1    0
#  2    0
#  3    0
#  4    0
#  Name: target, dtype: int32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
target.unique()
# Out:
# array([0, 1, 2])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data.values, target.values, test_size = 0.2, random_state = 2)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.models.Sequential([
keras.layers.Dense(units = 10, input_shape = (4, )),
keras.layers.Dense(units = 1)
])

model.compile(optimizer = "adam", loss="CategoricalCrossentropy", metrics=["accuracy"])

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(model, X_train, y_train, X_test, y_test)

print(f" Bias: {avg_bias}\n Variance: {avg_var}")

# %%
model1 = keras.models.Sequential([
keras.layers.Dense(units = 10, input_shape = (4, )),
keras.layers.Dense(units = 32, activation= 'relu'),
keras.layers.Dense(units = 1)
])

model1.compile(optimizer= 'adam', loss="CategoricalCrossentropy", metrics=["accuracy"])

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(model1, X_train, y_train, X_test, y_test)
print(f"Bias: {round(avg_bias,4)}\n Variance: {round(avg_var, 4)}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2829 - loss: 1.4196e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.4723 - loss: 1.1839e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3594 - loss: 1.3359e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3125 - loss: 1.0376e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3635 - loss: 1.2539e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2919 - loss: 1.1327e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3540 - loss: 1.2077e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3137 - loss: 1.2477e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# ...

# %%
model2 = keras.models.Sequential([
keras.layers.Dense(units = 10, input_shape = (4, )),
keras.layers.Dense(units = 32, activation= 'relu'),
keras.layers.Dense(units = 32, activation= 'relu'),
keras.layers.Dense(units = 1)
])

model2.compile(optimizer= 'adam', loss="CategoricalCrossentropy", metrics=["accuracy"])

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(model2, X_train, y_train, X_test, y_test)
print(f"Bias: {round(avg_bias,4)}\n Variance: {round(avg_var, 4)}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2677 - loss: 1.3063e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2683 - loss: 1.2594e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3046 - loss: 1.1869e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3242 - loss: 1.2681e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2533 - loss: 1.2778e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2594 - loss: 1.3803e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2713 - loss: 1.2574e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2954 - loss: 1.2641e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# ...

# %%
model2 = keras.models.Sequential([
keras.layers.Dense(units = 10, input_shape = (4, )),
keras.layers.Dense(units = 32, activation= 'relu'),
keras.layers.Dense(units = 32, activation= 'relu'),
keras.layers.Dense(units = 16, activation= 'relu'),
keras.layers.Dense(units = 1)
])

model2.compile(optimizer= 'adam', loss="CategoricalCrossentropy", metrics=["accuracy"])

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(model2, X_train, y_train, X_test, y_test)
print(f"Bias: {round(avg_bias,4)}\n Variance: {round(avg_var, 4)}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 0s/step - accuracy: 0.2573 - loss: 1.3366e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2252 - loss: 1.3863e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2842 - loss: 1.2510e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1979 - loss: 1.5152e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3833 - loss: 1.1516e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2933 - loss: 1.3555e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3490 - loss: 1.0779e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2971 - loss: 1.2885e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ...

# %%
model2 = keras.models.Sequential([
keras.layers.Dense(units = 10, input_shape = (4, )),
keras.layers.Dense(units = 32, activation= 'relu'),
keras.layers.Dense(units = 32, activation= 'relu'),
keras.layers.Dense(units = 16, activation= 'relu'),
keras.layers.Dense(units = 8, activation= 'relu'),
keras.layers.Dense(units = 1)
])

model2.compile(optimizer= 'adam', loss="CategoricalCrossentropy", metrics=["accuracy"])

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(model2, X_train, y_train, X_test, y_test)
print(f"Bias: {round(avg_bias,4)}\n Variance: {round(avg_var, 4)}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2304 - loss: 1.2045e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3415 - loss: 1.2599e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3612 - loss: 1.2477e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3144 - loss: 1.1347e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3204 - loss: 1.2512e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3367 - loss: 1.1921e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4283 - loss: 1.1201e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3148 - loss: 1.2087e-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ...

# %% [markdown]
# ## Exploring Variance

# %%
from sklearn.tree import DecisionTreeClassifier

cls = DecisionTreeClassifier()
cls.fit(X_train, y_train)

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(cls, X_train, y_train, X_test, y_test)
print(f"Bias: {round(avg_bias,4)}\n Variance: {round(avg_var, 4)}")
# Out:
# Bias: 0.0333
#  Variance: 0.0182

# %%
from sklearn.linear_model import LogisticRegression

cls = LogisticRegression()
cls.fit(X_train, y_train)

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(cls, X_train, y_train, X_test, y_test)
print(f"Bias: {round(avg_bias,4)}\n Variance: {round(avg_var, 4)}")
# Out:
# Bias: 0.0333
#  Variance: 0.0085

# %%
from sklearn.ensemble import RandomForestClassifier

cls = RandomForestClassifier()
cls.fit(X_train, y_train)

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(cls, X_train, y_train, X_test, y_test)
print(f"Bias: {round(avg_bias,4)}\n Variance: {round(avg_var, 4)}")
# Out:
# Bias: 0.0333
#  Variance: 0.008

# %%
from sklearn.naive_bayes import MultinomialNB

cls = MultinomialNB()
cls.fit(X_train, y_train)

avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(cls, X_train, y_train, X_test, y_test)
print(f"Bias: {round(avg_bias,4)}\n Variance: {round(avg_var, 4)}")
# Out:
# Bias: 0.0333
#  Variance: 0.178
